# %% [markdown]
# ## Neighborhood Segmentation and Clustering - Week 3

# %% [markdown]
# Scrape the following Wikipedia page, https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M, in order to obtain the data that is in the table of postal codes and to transform the data into a pandas dataframe

# %%
# Libraries
import folium
import requests
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
from geopy.geocoders import Nominatim
from pandas.io.json import json_normalize

# %%
def scrape_site(url):
    headers = requests.utils.default_headers()
    headers.update({
        'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0',
    })
    r = requests.get(url, headers)
    raw_html = r.content
    soup = BeautifulSoup(raw_html, 'html.parser')
    return soup

# %%
def get_table(soup, class_name):
    information = []
    table = soup.find("table", class_=class_name)
    table_rows = table.find_all('tr')
    for row in table_rows:
        info = row.text.split('\n')[1:-1]
        information.append(info)
    return information

# %% [markdown]
# Create Dataframe from url

# %%
# Set info
url   = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
soup = scrape_site(url)
data_table = get_table(soup, 'wikitable')
data_table = pd.DataFrame(data_table[1:], columns=data_table[0])

# Fix name Neighbourhood to Neighborhood
data_table = data_table.rename(columns={data_table.columns[2]: "Neighborhood" })
data_table
# Out:
#     Postcode           Borough  \
# 0        M1A      Not assigned
# 1        M2A      Not assigned
# 2        M3A        North York
# 3        M4A        North York
# 4        M5A  Downtown Toronto
# 5        M5A  Downtown Toronto
# 6        M6A        North York
# 7        M6A        North York
# 8        M7A      Queen's Park
# 9        M8A      Not assigned
# 10       M9A         Etobicoke
# 11       M1B       Scarborough
# 12       M1B       Scarborough
# 13       M2B      Not assigned
# 14       M3B        North York
# 15       M4B         East York
# 16       M4B         East York
# 17       M5B  Downtown Toronto
# 18       M5B  Downtown Toronto
# 19       M6B        North York
# 20       M7B      Not assigned
# 21       M8B      Not assigned
# 22       M9B         Etobicoke
# 23       M9B         Etobicoke
# 24       M9B         Etobicoke
# 25       M9B         Etobicoke
# 26       M9B         Etobicoke
# 27       M1C       Scarborough
# 28       M1C       Scarborough
# 29       M1C       Scarborough
# ..       ...               ...
# 258      M9X      Not assigned
# 259      M1Y      Not assigned
# 260      M2Y      Not assigned
# 261      M3Y      Not assigned
# 262      M4Y  Downtown Toronto
# 263      M5Y      Not assigned
# 264      M6Y      Not assigned
# 265      M7Y      East Toronto
# 266      M8Y         Etobicoke
# 267      M8Y         Etobicoke
# 268      M8Y         Etobicoke
# 269      M8Y         Etobicoke
# 270      M8Y         Etobicoke
# 271      M8Y         Etobicoke
# 272      M8Y         Etobicoke
# 273      M8Y         Etobicoke
# 274      M9Y      Not assigned
# 275      M1Z      Not assigned
# 276      M2Z      Not assigned
# 277      M3Z      Not assigned
# 278      M4Z      Not assigned
# 279      M5Z      Not assigned
# 280      M6Z      Not assigned
# 281      M7Z      Not assigned
# 282      M8Z         Etobicoke
# 283      M8Z         Etobicoke
# 284      M8Z         Etobicoke
# 285      M8Z         Etobicoke
# 286      M8Z         Etobicoke
# 287      M9Z      Not assigned
#
#                                           Neighborhood
# 0                                         Not assigned
# 1                                         Not assigned
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                                         Harbourfront
# 5                                          Regent Park
# 6                                     Lawrence Heights
# 7                                       Lawrence Manor
# 8                                         Not assigned
# 9                                         Not assigned
# 10                                    Islington Avenue
# 11                                               Rouge
# 12                                             Malvern
# 13                                        Not assigned
# 14                                     Don Mills North
# 15                                    Woodbine Gardens
# 16                                       Parkview Hill
# 17                                             Ryerson
# 18                                     Garden District
# 19                                           Glencairn
# 20                                        Not assigned
# 21                                        Not assigned
# 22                                          Cloverdale
# 23                                           Islington
# 24                                        Martin Grove
# 25                                    Princess Gardens
# 26                                     West Deane Park
# 27                                      Highland Creek
# 28                                          Rouge Hill
# 29                                          Port Union
# ..                                                 ...
# 258                                       Not assigned
# 259                                       Not assigned
# 260                                       Not assigned
# 261                                       Not assigned
# 262                               Church and Wellesley
# 263                                       Not assigned
# 264                                       Not assigned
# 265  Business Reply Mail Processing Centre 969 Eastern
# 266                                         Humber Bay
# 267                                   King's Mill Park
# 268                           Kingsway Park South East
# 269                                          Mimico NE
# 270                                     Old Mill South
# 271                                 The Queensway East
# 272                              Royal York South East
# 273                                           Sunnylea
# 274                                       Not assigned
# 275                                       Not assigned
# 276                                       Not assigned
# 277                                       Not assigned
# 278                                       Not assigned
# 279                                       Not assigned
# 280                                       Not assigned
# 281                                       Not assigned
# 282                           Kingsway Park South West
# 283                                          Mimico NW
# 284                                 The Queensway West
# 285                              Royal York South West
# 286                                     South of Bloor
# 287                                       Not assigned
#
# [288 rows x 3 columns]

# %% [markdown]
# Process the cells that have an assigned borough. Ignore cells with a borough that is Not assigned.

# %%
clean_table = data_table[data_table.Borough != 'Not assigned']
clean_table.reset_index(drop=True)
clean_table
# Out:
#     Postcode           Borough  \
# 2        M3A        North York
# 3        M4A        North York
# 4        M5A  Downtown Toronto
# 5        M5A  Downtown Toronto
# 6        M6A        North York
# 7        M6A        North York
# 8        M7A      Queen's Park
# 10       M9A         Etobicoke
# 11       M1B       Scarborough
# 12       M1B       Scarborough
# 14       M3B        North York
# 15       M4B         East York
# 16       M4B         East York
# 17       M5B  Downtown Toronto
# 18       M5B  Downtown Toronto
# 19       M6B        North York
# 22       M9B         Etobicoke
# 23       M9B         Etobicoke
# 24       M9B         Etobicoke
# 25       M9B         Etobicoke
# 26       M9B         Etobicoke
# 27       M1C       Scarborough
# 28       M1C       Scarborough
# 29       M1C       Scarborough
# 31       M3C        North York
# 32       M3C        North York
# 33       M4C         East York
# 34       M5C  Downtown Toronto
# 35       M6C              York
# 38       M9C         Etobicoke
# ..       ...               ...
# 235      M9V         Etobicoke
# 236      M1W       Scarborough
# 239      M4W  Downtown Toronto
# 240      M5W  Downtown Toronto
# 243      M8W         Etobicoke
# 244      M8W         Etobicoke
# 245      M9W         Etobicoke
# 246      M1X       Scarborough
# 249      M4X  Downtown Toronto
# 250      M4X  Downtown Toronto
# 251      M5X  Downtown Toronto
# 252      M5X  Downtown Toronto
# 255      M8X         Etobicoke
# 256      M8X         Etobicoke
# 257      M8X         Etobicoke
# 262      M4Y  Downtown Toronto
# 265      M7Y      East Toronto
# 266      M8Y         Etobicoke
# 267      M8Y         Etobicoke
# 268      M8Y         Etobicoke
# 269      M8Y         Etobicoke
# 270      M8Y         Etobicoke
# 271      M8Y         Etobicoke
# 272      M8Y         Etobicoke
# 273      M8Y         Etobicoke
# 282      M8Z         Etobicoke
# 283      M8Z         Etobicoke
# 284      M8Z         Etobicoke
# 285      M8Z         Etobicoke
# 286      M8Z         Etobicoke
#
#                                           Neighborhood
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                                         Harbourfront
# 5                                          Regent Park
# 6                                     Lawrence Heights
# 7                                       Lawrence Manor
# 8                                         Not assigned
# 10                                    Islington Avenue
# 11                                               Rouge
# 12                                             Malvern
# 14                                     Don Mills North
# 15                                    Woodbine Gardens
# 16                                       Parkview Hill
# 17                                             Ryerson
# 18                                     Garden District
# 19                                           Glencairn
# 22                                          Cloverdale
# 23                                           Islington
# 24                                        Martin Grove
# 25                                    Princess Gardens
# 26                                     West Deane Park
# 27                                      Highland Creek
# 28                                          Rouge Hill
# 29                                          Port Union
# 31                                     Flemingdon Park
# 32                                     Don Mills South
# 33                                    Woodbine Heights
# 34                                      St. James Town
# 35                                  Humewood-Cedarvale
# 38                                   Bloordale Gardens
# ..                                                 ...
# 235                                        Thistletown
# 236                                    L'Amoreaux West
# 239                                           Rosedale
# 240                    Stn A PO Boxes 25 The Esplanade
# 243                                          Alderwood
# 244                                        Long Branch
# 245                                          Northwest
# 246                                        Upper Rouge
# 249                                        Cabbagetown
# 250                                     St. James Town
# 251                               First Canadian Place
# 252                                   Underground city
# 255                                       The Kingsway
# 256                                    Montgomery Road
# 257                                     Old Mill North
# 262                               Church and Wellesley
# 265  Business Reply Mail Processing Centre 969 Eastern
# 266                                         Humber Bay
# 267                                   King's Mill Park
# 268                           Kingsway Park South East
# 269                                          Mimico NE
# 270                                     Old Mill South
# 271                                 The Queensway East
# 272                              Royal York South East
# 273                                           Sunnylea
# 282                           Kingsway Park South West
# 283                                          Mimico NW
# 284                                 The Queensway West
# 285                              Royal York South West
# 286                                     South of Bloor
#
# [211 rows x 3 columns]

# %% [markdown]
# Merge Neighborhood and group by Borough

# %%
grouped_data = clean_table.groupby(['Postcode','Borough'])['Neighborhood'].apply(', '.join).reset_index()
grouped_data
# Out:
#     Postcode           Borough  \
# 0        M1B       Scarborough
# 1        M1C       Scarborough
# 2        M1E       Scarborough
# 3        M1G       Scarborough
# 4        M1H       Scarborough
# 5        M1J       Scarborough
# 6        M1K       Scarborough
# 7        M1L       Scarborough
# 8        M1M       Scarborough
# 9        M1N       Scarborough
# 10       M1P       Scarborough
# 11       M1R       Scarborough
# 12       M1S       Scarborough
# 13       M1T       Scarborough
# 14       M1V       Scarborough
# 15       M1W       Scarborough
# 16       M1X       Scarborough
# 17       M2H        North York
# 18       M2J        North York
# 19       M2K        North York
# 20       M2L        North York
# 21       M2M        North York
# 22       M2N        North York
# 23       M2P        North York
# 24       M2R        North York
# 25       M3A        North York
# 26       M3B        North York
# 27       M3C        North York
# 28       M3H        North York
# 29       M3J        North York
# ..       ...               ...
# 73       M6C              York
# 74       M6E              York
# 75       M6G  Downtown Toronto
# 76       M6H      West Toronto
# 77       M6J      West Toronto
# 78       M6K      West Toronto
# 79       M6L        North York
# 80       M6M              York
# 81       M6N              York
# 82       M6P      West Toronto
# 83       M6R      West Toronto
# 84       M6S      West Toronto
# 85       M7A      Queen's Park
# 86       M7R       Mississauga
# 87       M7Y      East Toronto
# 88       M8V         Etobicoke
# 89       M8W         Etobicoke
# 90       M8X         Etobicoke
# 91       M8Y         Etobicoke
# 92       M8Z         Etobicoke
# 93       M9A         Etobicoke
# 94       M9B         Etobicoke
# 95       M9C         Etobicoke
# 96       M9L        North York
# 97       M9M        North York
# 98       M9N              York
# 99       M9P         Etobicoke
# 100      M9R         Etobicoke
# 101      M9V         Etobicoke
# 102      M9W         Etobicoke
#
#                                           Neighborhood
# 0                                       Rouge, Malvern
# 1               Highland Creek, Rouge Hill, Port Union
# 2                    Guildwood, Morningside, West Hill
# 3                                               Woburn
# 4                                            Cedarbrae
# 5                                  Scarborough Village
# 6          East Birchmount Park, Ionview, Kennedy Park
# 7                      Clairlea, Golden Mile, Oakridge
# 8      Cliffcrest, Cliffside, Scarborough Village West
# 9                          Birch Cliff, Cliffside West
# 10   Dorset Park, Scarborough Town Centre, Wexford ...
# 11                                   Maryvale, Wexford
# 12                                           Agincourt
# 13             Clarks Corners, Sullivan, Tam O'Shanter
# 14   Agincourt North, L'Amoreaux East, Milliken, St...
# 15                                     L'Amoreaux West
# 16                                         Upper Rouge
# 17                                   Hillcrest Village
# 18                        Fairview, Henry Farm, Oriole
# 19                                     Bayview Village
# 20                            Silver Hills, York Mills
# 21                             Newtonbrook, Willowdale
# 22                                    Willowdale South
# 23                                     York Mills West
# 24                                     Willowdale West
# 25                                           Parkwoods
# 26                                     Don Mills North
# 27                    Flemingdon Park, Don Mills South
# 28     Bathurst Manor, Downsview North, Wilson Heights
# 29                     Northwood Park, York University
# ..                                                 ...
# 73                                  Humewood-Cedarvale
# 74                                 Caledonia-Fairbanks
# 75                                            Christie
# 76                        Dovercourt Village, Dufferin
# 77                            Little Portugal, Trinity
# 78        Brockton, Exhibition Place, Parkdale Village
# 79                  Downsview, North Park, Upwood Park
# 80      Del Ray, Keelesdale, Mount Dennis, Silverthorn
# 81                       The Junction North, Runnymede
# 82                       High Park, The Junction South
# 83                              Parkdale, Roncesvalles
# 84                                  Runnymede, Swansea
# 85                                        Not assigned
# 86               Canada Post Gateway Processing Centre
# 87   Business Reply Mail Processing Centre 969 Eastern
# 88        Humber Bay Shores, Mimico South, New Toronto
# 89                              Alderwood, Long Branch
# 90       The Kingsway, Montgomery Road, Old Mill North
# 91   Humber Bay, King's Mill Park, Kingsway Park So...
# 92   Kingsway Park South West, Mimico NW, The Queen...
# 93                                    Islington Avenue
# 94   Cloverdale, Islington, Martin Grove, Princess ...
# 95   Bloordale Gardens, Eringate, Markland Wood, Ol...
# 96                                       Humber Summit
# 97                                    Emery, Humberlea
# 98                                              Weston
# 99                                           Westmount
# 100  Kingsview Village, Martin Grove Gardens, Richv...
# 101  Albion Gardens, Beaumond Heights, Humbergate, ...
# 102                                          Northwest
#
# [103 rows x 3 columns]

# %% [markdown]
#  Print the number of rows of the dataframe

# %%
print('The DataFrame shape is:', grouped_data.shape)
# Out:
# The DataFrame shape is: (103, 3)

# %% [markdown]
# ## Add Latitude and Longitude columns

# %%
geo_data = pd.read_csv("http://cocl.us/Geospatial_data")
geo_data.rename(columns={'Postal Code':'Postcode'}, inplace=True)
geo_data.set_index("Postcode")
grouped_data.set_index("Postcode")
toronto_df = pd.merge(grouped_data, geo_data)
toronto_df.head()
# Out:
#   Postcode      Borough                            Neighborhood   Latitude  \
# 0      M1B  Scarborough                          Rouge, Malvern  43.806686
# 1      M1C  Scarborough  Highland Creek, Rouge Hill, Port Union  43.784535
# 2      M1E  Scarborough       Guildwood, Morningside, West Hill  43.763573
# 3      M1G  Scarborough                                  Woburn  43.770992
# 4      M1H  Scarborough                               Cedarbrae  43.773136
#
#    Longitude
# 0 -79.194353
# 1 -79.160497
# 2 -79.188711
# 3 -79.216917
# 4 -79.239476

# %%
address = 'Toronto, Canada'
geolocator = Nominatim(user_agent="Ontario_Clustering")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

print('The geograpical coordinate of Toronto, ON, Canada are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto, ON, Canada are 43.653963, -79.387207.

# %%
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

for lat, lng, borough, neighborhood in zip(toronto_df['Latitude'], toronto_df['Longitude'], toronto_df['Borough'], toronto_df['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=3,
        popup=label,
        color='#373F51',
        fill=True,
        fill_color='#373F51',
        fill_opacity=0.3,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Explore Toronto Neighbourhoods

# %%
# Filter Neighbourhoods
filter_df = toronto_df[toronto_df['Borough'].str.contains('Toronto')]
neighbourhoods_df = filter_df.reset_index(drop=True)
neighbourhoods_df.head()
# Out:
#   Postcode          Borough                    Neighborhood   Latitude  \
# 0      M4E     East Toronto                     The Beaches  43.676357
# 1      M4K     East Toronto    The Danforth West, Riverdale  43.679557
# 2      M4L     East Toronto  The Beaches West, India Bazaar  43.668999
# 3      M4M     East Toronto                 Studio District  43.659526
# 4      M4N  Central Toronto                   Lawrence Park  43.728020
#
#    Longitude
# 0 -79.293031
# 1 -79.352188
# 2 -79.315572
# 3 -79.340923
# 4 -79.388790

# %% [markdown]
# Select Studio District neighbourhood properties

# %%
neighbourhood = neighbourhoods_df.loc[1]
neighbourhood_latitude = neighbourhood['Latitude']
neighbourhood_longitude = neighbourhood['Longitude']
neighbourhood_name = neighbourhood['Neighborhood']

# %%
# Set Foursquare API config
CLIENT_ID = 'EXERCOQ420QGNLZ3JWZDOYYC0P2TSG3UW5VRSQMG40YJJAGL'
CLIENT_SECRET = 'DQJQABOZFJBWKBMWPTJFEUV5KNNKYFIBMOJBQRP5BSGTMHIQ'
VERSION = '20190419' # Set version name like yearmonthday string

# %%
def format_url(lat, lng, radius=500, limit=100):
    return 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, 
        lat, lng, VERSION, radius, limit)

def get_api_data(url):
    result = requests.get(url).json()
    return result

# %%
url = format_url(neighbourhood_latitude, neighbourhood_longitude)
api_response = get_api_data(url)
api_response
# Out:
# {'meta': {'code': 200, 'requestId': '5cba83d51ed2196d944066bf'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Greektown',
#   'headerFullLocation': 'Greektown, Toronto',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 44,
#   'suggestedBounds': {'ne': {'lat': 43.6840571045, 'lng': -79.34597738331301},
#    'sw': {'lat': 43.675057095499994, 'lng': -79.35839861668698}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dc72844d22dafda2fcf75e6',
#        'name': 'Dolce Gelato',
#        'location': {'address': '414 Danforth Ave',
#         'lat': 43.677772998450614,
#         'lng': -79.35118737317053,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.677772998450614,
#           'lng': -79.35118737317053}],
#         'distance': 214,
#         'postalCode': 'M4K 1P3',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['414 Danforth Ave',
#          'Toronto ON M4K 1P3',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'shortName': 'Ice Cream',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dc72844d22dafda2fcf75e6-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bce4183ef10952197da8386',
#        'name': 'Pantheon',
#        'location': {'address': '407 Danforth Ave.',
#         'crossStreet': 'at Chester Ave.',
#         'lat': 43.67762124481265,
#         'lng': -79.35143390043564,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67762124481265,
#           'lng': -79.35143390043564}],
#         'distance': 223,
#         'postalCode': 'M4K 1P1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['407 Danforth Ave. (at Chester Ave.)',
#          'Toronto ON M4K 1P1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d10e941735',
#          'name': 'Greek Restaurant',
#          'pluralName': 'Greek Restaurants',
#          'shortName': 'Greek',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bce4183ef10952197da8386-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5102df8df13673cd7084ac39',
#        'name': 'MenEssentials',
#        'location': {'address': '412 Danforth Ave.',
#         'crossStreet': 'Near Danforth and Chester',
#         'lat': 43.677820068604575,
#         'lng': -79.35126543045044,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.677820068604575,
#           'lng': -79.35126543045044}],
#         'distance': 207,
#         'postalCode': 'M4K 1P3',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['412 Danforth Ave. (Near Danforth and Chester)',
#          'Toronto ON M4K 1P3',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d10c951735',
#          'name': 'Cosmetics Shop',
#          'pluralName': 'Cosmetics Shops',
#          'shortName': 'Cosmetics',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/beauty_cosmetic_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '50073247'}},
#       'referralId': 'e-0-5102df8df13673cd7084ac39-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4afdfadff964a520a52c22e3',
#        'name': 'Mezes',
#        'location': {'address': '456 Danforth Ave',
#         'crossStreet': 'at Logan Ave.',
#         'lat': 43.6779622615441,
#         'lng': -79.35019606997218,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.6779622615441,
#           'lng': -79.35019606997218}],
#         'distance': 239,
#         'postalCode': 'M4K 1P4',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['456 Danforth Ave (at Logan Ave.)',
#          'Toronto ON M4K 1P4',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d10e941735',
#          'name': 'Greek Restaurant',
#          'pluralName': 'Greek Restaurants',
#          'shortName': 'Greek',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4afdfadff964a520a52c22e3-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4aeb268bf964a52006bf21e3',
#        'name': 'Messini Authentic Gyros',
#        'location': {'address': '445 Danforth Ave',
#         'crossStreet': 'at Logan Ave',
#         'lat': 43.677827494513096,
#         'lng': -79.35056873157725,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.677827494513096,
#           'lng': -79.35056873157725}],
#         'distance': 232,
#         'postalCode': 'M4K 1P1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['445 Danforth Ave (at Logan Ave)',
#          'Toronto ON M4K 1P1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d10e941735',
#          'name': 'Greek Restaurant',
#          'pluralName': 'Greek Restaurants',
#          'shortName': 'Greek',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4aeb268bf964a52006bf21e3-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e3dbb5e45dd68e3273e03b7',
#        'name': 'Cafe Fiorentina',
#        'location': {'address': '463 Danforth Ave',
#         'crossStreet': 'Logan Ave',
#         'lat': 43.677743,
#         'lng': -79.350115,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.677743,
#           'lng': -79.350115}],
#         'distance': 261,
#         'postalCode': 'M4K 1P1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['463 Danforth Ave (Logan Ave)',
#          'Toronto ON M4K 1P1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e3dbb5e45dd68e3273e03b7-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b64ce4af964a52084d12ae3',
#        'name': "Christina's On The Danforth",
#        'location': {'address': '492 Danforth Avenue',
#         'crossStreet': '& Logan Av',
#         'lat': 43.678239784878826,
#         'lng': -79.34918494943804,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.678239784878826,
#           'lng': -79.34918494943804}],
#         'distance': 282,
#         'postalCode': 'M4K 1P6',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['492 Danforth Avenue (& Logan Av)',
#          'Toronto ON M4K 1P6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d10e941735',
#          'name': 'Greek Restaurant',
#          'pluralName': 'Greek Restaurants',
#          'shortName': 'Greek',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b64ce4af964a52084d12ae3-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '541ed0a3498e7ff705517bcd',
#        'name': 'Louis Cifer Brew Works',
#        'location': {'address': '417 Danforth Ave',
#         'crossStreet': 'at Chester Ave',
#         'lat': 43.677662745359996,
#         'lng': -79.3513125762371,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.677662745359996,
#           'lng': -79.3513125762371}],
#         'distance': 222,
#         'postalCode': 'M4K 1P1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['417 Danforth Ave (at Chester Ave)',
#          'Toronto ON M4K 1P1',
#          'Canada']},
#        'categories': [{'id': '50327c8591d4c4b30a586d5d',
#          'name': 'Brewery',
#          'pluralName': 'Breweries',
#          'shortName': 'Brewery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '95245706'}},
#       'referralId': 'e-0-541ed0a3498e7ff705517bcd-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b677c35f964a520c7512be3',
#        'name': 'Moksha Yoga Danforth',
#        'location': {'address': '372 Danforth Ave',
#         'crossStreet': 'at Chester Ave',
#         'lat': 43.67762174479883,
#         'lng': -79.3521159367257,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67762174479883,
#           'lng': -79.3521159367257}],
#         'distance': 215,
#         'postalCode': 'M4K 1N8',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['372 Danforth Ave (at Chester Ave)',
#          'Toronto ON M4K 1N8',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b677c35f964a520c7512be3-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4af4e0d0f964a5202ff721e3',
#        'name': '7 Numbers',
#        'location': {'address': '307 Danforth Ave.',
#         'crossStreet': 'at Bowden St',
#         'lat': 43.677061774959824,
#         'lng': -79.35393428891682,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.677061774959824,
#           'lng': -79.35393428891682}],
#         'distance': 311,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['307 Danforth Ave. (at Bowden St)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4af4e0d0f964a5202ff721e3-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ae24088f964a5206b8c21e3',
#        'name': 'The Auld Spot Pub',
#        'location': {'address': '347 Danforth Ave',
#         'crossStreet': 'at Hampton Ave',
#         'lat': 43.67733505610778,
#         'lng': -79.35312964755529,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67733505610778,
#           'lng': -79.35312964755529}],
#         'distance': 258,
#         'postalCode': 'M4K 1N7',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['347 Danforth Ave (at Hampton Ave)',
#          'Toronto ON M4K 1N7',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d11b941735',
#          'name': 'Pub',
#          'pluralName': 'Pubs',
#          'shortName': 'Pub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ae24088f964a5206b8c21e3-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57799e91498e189817c91ead',
#        'name': 'La Diperie',
#        'location': {'address': '372 Danforth Ave',
#         'lat': 43.67753,
#         'lng': -79.352295,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67753,
#           'lng': -79.352295}],
#         'distance': 225,
#         'postalCode': 'M4K 1P1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['372 Danforth Ave',
#          'Toronto ON M4K 1P1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'shortName': 'Ice Cream',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57799e91498e189817c91ead-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ec857560e6158baffa4fc3c',
#        'name': 'Pizzeria Libretto',
#        'location': {'address': '550 Danforth Ave',
#         'crossStreet': 'at Carlaw Ave',
#         'lat': 43.678488633358,
#         'lng': -79.34757579277853,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.678488633358,
#           'lng': -79.34757579277853}],
#         'distance': 389,
#         'postalCode': 'M4K 1P7',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['550 Danforth Ave (at Carlaw Ave)',
#          'Toronto ON M4K 1P7',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ec857560e6158baffa4fc3c-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bb2727135f0c9b66749bb83',
#        'name': 'Valley Farm Produce',
#        'location': {'address': '466 Danforth Ave',
#         'crossStreet': 'at Logan Ave',
#         'lat': 43.677999294687275,
#         'lng': -79.3499690927287,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.677999294687275,
#           'lng': -79.3499690927287}],
#         'distance': 248,
#         'postalCode': 'M4K 1P4',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['466 Danforth Ave (at Logan Ave)',
#          'Toronto ON M4K 1P4',
#          'Canada']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b1c',
#          'name': 'Fruit & Vegetable Store',
#          'pluralName': 'Fruit & Vegetable Stores',
#          'shortName': 'Fruit & Vegetable Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bb2727135f0c9b66749bb83-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b466804f964a520ed1f26e3',
#        'name': 'Caffé Demetre',
#        'location': {'address': '400 Danforth Ave',
#         'crossStreet': 'Chester & Arundel',
#         'lat': 43.67768266377745,
#         'lng': -79.35160842812537,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67768266377745,
#           'lng': -79.35160842812537}],
#         'distance': 213,
#         'postalCode': 'M4K 1P3',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['400 Danforth Ave (Chester & Arundel)',
#          'Toronto ON M4K 1P3',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1d0941735',
#          'name': 'Dessert Shop',
#          'pluralName': 'Dessert Shops',
#          'shortName': 'Desserts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b466804f964a520ed1f26e3-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b26a6a9f964a520ff7e24e3',
#        'name': 'Re: Reading',
#        'location': {'address': '548 Danforth Ave.',
#         'crossStreet': 'Carlaw',
#         'lat': 43.678506570428084,
#         'lng': -79.34767758382526,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.678506570428084,
#           'lng': -79.34767758382526}],
#         'distance': 381,
#         'postalCode': 'M4K 1P8',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['548 Danforth Ave. (Carlaw)',
#          'Toronto ON M4K 1P8',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d114951735',
#          'name': 'Bookstore',
#          'pluralName': 'Bookstores',
#          'shortName': 'Bookstore',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b26a6a9f964a520ff7e24e3-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5916090a69e77b035ceb1a86',
#        'name': 'Rikkochez',
#        'location': {'address': '341 Danforth Ave',
#         'crossStreet': 'across from Carrot Common — TTC: Chester',
#         'lat': 43.677267,
#         'lng': -79.353274,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.677267,
#           'lng': -79.353274}],
#         'distance': 269,
#         'postalCode': 'M4K 1N7',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['341 Danforth Ave (across from Carrot Common — TTC: Chester)',
#          'Toronto ON M4K 1N7',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '419057819'}},
#       'referralId': 'e-0-5916090a69e77b035ceb1a86-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c1d5337eac020a1cb1048c2',
#        'name': 'Sher-E-Punjab',
#        'location': {'address': '351 Danforth Ave',
#         'crossStreet': 'at Jackman Ave',
#         'lat': 43.67730788939673,
#         'lng': -79.35306551709385,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67730788939673,
#           'lng': -79.35306551709385}],
#         'distance': 260,
#         'postalCode': 'M4K 1N7',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['351 Danforth Ave (at Jackman Ave)',
#          'Toronto ON M4K 1N7',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c1d5337eac020a1cb1048c2-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bd1db4e046076b0f1a57271',
#        'name': 'The Big Carrot Organic Juice Bar',
#        'location': {'address': '348 Danforth Ave',
#         'crossStreet': 'Hampton Avenue',
#         'lat': 43.677438,
#         'lng': -79.352683,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.677438,
#           'lng': -79.352683}],
#         'distance': 239,
#         'postalCode': 'M4K 1N8',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['348 Danforth Ave (Hampton Avenue)',
#          'Toronto ON M4K 1N8',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d112941735',
#          'name': 'Juice Bar',
#          'pluralName': 'Juice Bars',
#          'shortName': 'Juice Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/juicebar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bd1db4e046076b0f1a57271-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bbe3c929474c9b6d54cd9b6',
#        'name': "Athen's Pastries",
#        'location': {'address': '509 Danforth Ave.',
#         'crossStreet': 'at Fenwick Ave.',
#         'lat': 43.67816589533113,
#         'lng': -79.34892679522846,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67816589533113,
#           'lng': -79.34892679522846}],
#         'distance': 304,
#         'cc': 'CA',
#         'neighborhood': 'Riverdale',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['509 Danforth Ave. (at Fenwick Ave.)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d10e941735',
#          'name': 'Greek Restaurant',
#          'pluralName': 'Greek Restaurants',
#          'shortName': 'Greek',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bbe3c929474c9b6d54cd9b6-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4be9a0a46295c9b697738508',
#        'name': 'Don Valley Trail',
#        'location': {'lat': 43.67633091997674,
#         'lng': -79.35392333297455,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67633091997674,
#           'lng': -79.35392333297455}],
#         'distance': 385,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['Toronto ON', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d159941735',
#          'name': 'Trail',
#          'pluralName': 'Trails',
#          'shortName': 'Trail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/hikingtrail_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4be9a0a46295c9b697738508-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ae29e2af964a520338f21e3',
#        'name': 'Alexandros',
#        'location': {'address': '484 Danforth Ave',
#         'crossStreet': 'Logan Ave',
#         'lat': 43.67830448799868,
#         'lng': -79.34948556208978,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67830448799868,
#           'lng': -79.34948556208978}],
#         'distance': 258,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['484 Danforth Ave (Logan Ave)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d10e941735',
#          'name': 'Greek Restaurant',
#          'pluralName': 'Greek Restaurants',
#          'shortName': 'Greek',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ae29e2af964a520338f21e3-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c508ae15ee81b8d9ee3c5fe',
#        'name': 'Tsaa Tea Shop',
#        'location': {'address': 'Danforth',
#         'crossStreet': 'Chester',
#         'lat': 43.67776898684133,
#         'lng': -79.35130446081268,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67776898684133,
#           'lng': -79.35130446081268}],
#         'distance': 211,
#         'postalCode': 'M4k 3e3',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['Danforth (Chester)',
#          'Toronto ON M4k 3e3',
#          'Canada']},
#        'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#          'name': 'Bubble Tea Shop',
#          'pluralName': 'Bubble Tea Shops',
#          'shortName': 'Bubble Tea',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c508ae15ee81b8d9ee3c5fe-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b396a9ef964a520495c25e3',
#        'name': 'Pan on the Danforth',
#        'location': {'address': '516 Danforth Ave.',
#         'lat': 43.678263168189865,
#         'lng': -79.34864777195595,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.678263168189865,
#           'lng': -79.34864777195595}],
#         'distance': 319,
#         'postalCode': 'M4K 1P6',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['516 Danforth Ave.',
#          'Toronto ON M4K 1P6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d10e941735',
#          'name': 'Greek Restaurant',
#          'pluralName': 'Greek Restaurants',
#          'shortName': 'Greek',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b396a9ef964a520495c25e3-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad4c05ff964a52042f720e3',
#        'name': 'Astoria Shish Kebob House',
#        'location': {'address': '390 Danforth Ave',
#         'crossStreet': 'at Chester Ave',
#         'lat': 43.67768890877185,
#         'lng': -79.35189216872803,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67768890877185,
#           'lng': -79.35189216872803}],
#         'distance': 209,
#         'postalCode': 'M4K 1P3',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['390 Danforth Ave (at Chester Ave)',
#          'Toronto ON M4K 1P3',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d10e941735',
#          'name': 'Greek Restaurant',
#          'pluralName': 'Greek Restaurants',
#          'shortName': 'Greek',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ad4c05ff964a52042f720e3-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '548b33b0498e29d276209eca',
#        'name': 'IQ Living',
#        'location': {'address': '542 Danforth Ave',
#         'crossStreet': 'at Carlaw Ave',
#         'lat': 43.678477,
#         'lng': -79.347811,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.678477,
#           'lng': -79.347811}],
#         'distance': 372,
#         'postalCode': 'M4K 1P8',
#         'cc': 'CA',
#         'neighborhood': 'Greektown',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['542 Danforth Ave (at Carlaw Ave)',
#          'Toronto ON M4K 1P8',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1f8941735',
#          'name': 'Furniture / Home Store',
#          'pluralName': 'Furniture / Home Stores',
#          'shortName': 'Furniture / Home',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/furniture_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-548b33b0498e29d276209eca-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51520f12e4b0506736121eaf',
#        'name': 'Bulk Barn',
#        'location': {'address': '213 Danforth Ave',
#         'lat': 43.67678989740336,
#         'lng': -79.35586511284247,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67678989740336,
#           'lng': -79.35586511284247}],
#         'distance': 427,
#         'postalCode': 'M4K 1N2',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['213 Danforth Ave',
#          'Toronto ON M4K 1N2',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51520f12e4b0506736121eaf-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ae4bc2ff964a520909d21e3',
#        'name': 'Urban Nails',
#        'location': {'address': '179 Danforth Ave',
#         'lat': 43.676667789021906,
#         'lng': -79.35660190332753,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.676667789021906,
#           'lng': -79.35660190332753}],
#         'distance': 479,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['179 Danforth Ave', 'Toronto ON', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1ed941735',
#          'name': 'Spa',
#          'pluralName': 'Spas',
#          'shortName': 'Spa',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ae4bc2ff964a520909d21e3-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc10b17461576b00f537b32',
#        'name': 'Detroit Eatery',
#        'location': {'address': '389 Danforth Ave.',
#         'crossStreet': 'Chester',
#         'lat': 43.67759437002395,
#         'lng': -79.35176144372598,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67759437002395,
#           'lng': -79.35176144372598}],
#         'distance': 221,
#         'postalCode': 'M4K 1P1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['389 Danforth Ave. (Chester)',
#          'Toronto ON M4K 1P1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d147941735',
#          'name': 'Diner',
#          'pluralName': 'Diners',
#          'shortName': 'Diner',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc10b17461576b00f537b32-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4aec8fe3f964a520bcc821e3',
#        'name': 'Dough Bakeshop',
#        'location': {'address': '173 Danforth Ave.',
#         'crossStreet': 'Broadview',
#         'lat': 43.67664308520287,
#         'lng': -79.35684634585105,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67664308520287,
#           'lng': -79.35684634585105}],
#         'distance': 495,
#         'postalCode': 'M4K 1N2',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['173 Danforth Ave. (Broadview)',
#          'Toronto ON M4K 1N2',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4aec8fe3f964a520bcc821e3-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55fc0110498ecbc14aa76933',
#        'name': 'Marvel Coffee Co.',
#        'location': {'address': '792 Carlaw Ave.',
#         'crossStreet': 'Danforth',
#         'lat': 43.678644519699546,
#         'lng': -79.34743850749999,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.678644519699546,
#           'lng': -79.34743850749999}],
#         'distance': 395,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['792 Carlaw Ave. (Danforth)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55fc0110498ecbc14aa76933-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cec56edb80da09371e51b00',
#        'name': 'Sushi Friends',
#        'location': {'address': '397 Danforth Ave.',
#         'crossStreet': 'Chester Ave.',
#         'lat': 43.67761413097764,
#         'lng': -79.35164084535384,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67761413097764,
#           'lng': -79.35164084535384}],
#         'distance': 220,
#         'postalCode': 'M4K 1P1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['397 Danforth Ave. (Chester Ave.)',
#          'Toronto ON M4K 1P1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cec56edb80da09371e51b00-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5269ba3c498ea63de3eb987b',
#        'name': "Simone's Caribbean Restaurant",
#        'location': {'address': '596 Danforth Avenue',
#         'crossStreet': 'Pape And Danforth',
#         'lat': 43.67865547474292,
#         'lng': -79.34658157954753,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67865547474292,
#           'lng': -79.34658157954753}],
#         'distance': 462,
#         'postalCode': 'M4K 1R1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['596 Danforth Avenue (Pape And Danforth)',
#          'Toronto ON M4K 1R1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d144941735',
#          'name': 'Caribbean Restaurant',
#          'pluralName': 'Caribbean Restaurants',
#          'shortName': 'Caribbean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/caribbean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5269ba3c498ea63de3eb987b-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4af5de4ff964a5200cfe21e3',
#        'name': 'Second Cup',
#        'location': {'address': '355 Danforth Avenue',
#         'crossStreet': 'at Hampton Ave',
#         'lat': 43.67718757165012,
#         'lng': -79.3529747898985,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67718757165012,
#           'lng': -79.3529747898985}],
#         'distance': 271,
#         'postalCode': 'M4K 1N7',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['355 Danforth Avenue (at Hampton Ave)',
#          'Toronto ON M4K 1N7',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4af5de4ff964a5200cfe21e3-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b8d7b70f964a52063fe32e3',
#        'name': 'Cafe Frappe',
#        'location': {'address': '521 Danforth Ave.',
#         'crossStreet': 'Fenwick Avenue',
#         'lat': 43.67812618087551,
#         'lng': -79.34843379217203,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67812618087551,
#           'lng': -79.34843379217203}],
#         'distance': 341,
#         'postalCode': 'M4K 1P5',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['521 Danforth Ave. (Fenwick Avenue)',
#          'Toronto ON M4K 1P5',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b8d7b70f964a52063fe32e3-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4aeb2666f964a52005bf21e3',
#        'name': 'Brass Taps Pizza Pub',
#        'location': {'address': '493 Danforth Ave',
#         'crossStreet': 'at Logan Ave',
#         'lat': 43.67792441318533,
#         'lng': -79.34930702872876,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67792441318533,
#           'lng': -79.34930702872876}],
#         'distance': 294,
#         'postalCode': 'M4K 1P5',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['493 Danforth Ave (at Logan Ave)',
#          'Toronto ON M4K 1P5',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d11d941735',
#          'name': 'Sports Bar',
#          'pluralName': 'Sports Bars',
#          'shortName': 'Sports Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/sportsbar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4aeb2666f964a52005bf21e3-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d28fa67ebacb1f7f37ff64f',
#        'name': 'Factory Girl',
#        'location': {'address': '193 Danforth Ave.',
#         'lat': 43.67669287762859,
#         'lng': -79.35629876225282,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67669287762859,
#           'lng': -79.35629876225282}],
#         'distance': 459,
#         'postalCode': 'M4K 1N2',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['193 Danforth Ave.',
#          'Toronto ON M4K 1N2',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'shortName': 'American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d28fa67ebacb1f7f37ff64f-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b7846f5f964a52079c12ee3',
#        'name': 'Book City',
#        'location': {'address': '348 Danforth Avenue',
#         'crossStreet': 'near Chester',
#         'lat': 43.67741319707514,
#         'lng': -79.3527341009978,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67741319707514,
#           'lng': -79.3527341009978}],
#         'distance': 242,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['348 Danforth Avenue (near Chester)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d114951735',
#          'name': 'Bookstore',
#          'pluralName': 'Bookstores',
#          'shortName': 'Bookstore',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b7846f5f964a52079c12ee3-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d1263edd0fda0934094ab57',
#        'name': 'Leonidas Chocolates Cafe',
#        'location': {'address': 'Danforth Ave.',
#         'crossStreet': 'Logan Ave.',
#         'lat': 43.67811808012494,
#         'lng': -79.34948504099059,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67811808012494,
#           'lng': -79.34948504099059}],
#         'distance': 270,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['Danforth Ave. (Logan Ave.)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d1263edd0fda0934094ab57-38'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '516c9d2de4b0cde235a2cb1a',
#        'name': 'Menchies',
#        'location': {'address': 'Danforth Ave',
#         'crossStreet': 'Pape',
#         'lat': 43.67830909198205,
#         'lng': -79.34810528402672,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67830909198205,
#           'lng': -79.34810528402672}],
#         'distance': 356,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['Danforth Ave (Pape)', 'Toronto ON', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'shortName': 'Ice Cream',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-516c9d2de4b0cde235a2cb1a-39'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc0ea4df8219c74807ab210',
#        'name': 'LCBO',
#        'location': {'address': '200 Danforth Ave',
#         'crossStreet': 'btwn Pretoria & Playter',
#         'lat': 43.676815838008714,
#         'lng': -79.35604671347544,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.676815838008714,
#           'lng': -79.35604671347544}],
#         'distance': 435,
#         'postalCode': 'M4K 1N5',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['200 Danforth Ave (btwn Pretoria & Playter)',
#          'Toronto ON M4K 1N5',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d186941735',
#          'name': 'Liquor Store',
#          'pluralName': 'Liquor Stores',
#          'shortName': 'Liquor Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_liquor_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc0ea4df8219c74807ab210-40'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad89921f964a520b01221e3',
#        'name': 'Katsu Japanese Restaurant',
#        'location': {'address': '572 Danforth Ave',
#         'crossStreet': 'btwn Carlaw & Gough',
#         'lat': 43.67861856512561,
#         'lng': -79.34702430590903,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67861856512561,
#           'lng': -79.34702430590903}],
#         'distance': 428,
#         'postalCode': 'M4K 1R1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['572 Danforth Ave (btwn Carlaw & Gough)',
#          'Toronto ON M4K 1R1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'shortName': 'Sushi',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ad89921f964a520b01221e3-41'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5246dbd611d23c6130e650a0',
#        'name': 'Kitchen Stuff Plus',
#        'location': {'address': '583 Danforth Ave',
#         'crossStreet': 'at Gough Ave',
#         'lat': 43.67861256318158,
#         'lng': -79.34642163596001,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67861256318158,
#           'lng': -79.34642163596001}],
#         'distance': 475,
#         'postalCode': 'M4K 1P9',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['583 Danforth Ave (at Gough Ave)',
#          'Toronto ON M4K 1P9',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1f8941735',
#          'name': 'Furniture / Home Store',
#          'pluralName': 'Furniture / Home Stores',
#          'shortName': 'Furniture / Home',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/furniture_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5246dbd611d23c6130e650a0-42'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcba1cf964a520272f21e3',
#        'name': 'Starbucks',
#        'location': {'address': '604 Danforth Avenue',
#         'crossStreet': 'at Gough Ave.',
#         'lat': 43.67872968094713,
#         'lng': -79.34618766287778,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67872968094713,
#           'lng': -79.34618766287778}],
#         'distance': 491,
#         'postalCode': 'M4K 1R1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['604 Danforth Avenue (at Gough Ave.)',
#          'Toronto ON M4K 1R1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adcba1cf964a520272f21e3-43'}]}]}}

# %%
venues = api_response['response']['groups'][0]['items']
nearby_venues = json_normalize(venues) 
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues = nearby_venues.loc[:, filtered_columns]
nearby_venues
# Out:
#                           venue.name  \
# 0                       Dolce Gelato
# 1                           Pantheon
# 2                      MenEssentials
# 3                              Mezes
# 4            Messini Authentic Gyros
# 5                    Cafe Fiorentina
# 6        Christina's On The Danforth
# 7             Louis Cifer Brew Works
# 8               Moksha Yoga Danforth
# 9                          7 Numbers
# 10                 The Auld Spot Pub
# 11                        La Diperie
# 12                 Pizzeria Libretto
# 13               Valley Farm Produce
# 14                     Caffé Demetre
# 15                       Re: Reading
# 16                         Rikkochez
# 17                     Sher-E-Punjab
# 18  The Big Carrot Organic Juice Bar
# 19                  Athen's Pastries
# 20                  Don Valley Trail
# 21                        Alexandros
# 22                     Tsaa Tea Shop
# 23               Pan on the Danforth
# 24         Astoria Shish Kebob House
# 25                         IQ Living
# 26                         Bulk Barn
# 27                       Urban Nails
# 28                    Detroit Eatery
# 29                    Dough Bakeshop
# 30                 Marvel Coffee Co.
# 31                     Sushi Friends
# 32     Simone's Caribbean Restaurant
# 33                        Second Cup
# 34                       Cafe Frappe
# 35              Brass Taps Pizza Pub
# 36                      Factory Girl
# 37                         Book City
# 38          Leonidas Chocolates Cafe
# 39                          Menchies
# 40                              LCBO
# 41         Katsu Japanese Restaurant
# 42                Kitchen Stuff Plus
# 43                         Starbucks
#
#                                      venue.categories  venue.location.lat  \
# 0   [{'id': '4bf58dd8d48988d1c9941735', 'name': 'I...           43.677773
# 1   [{'id': '4bf58dd8d48988d10e941735', 'name': 'G...           43.677621
# 2   [{'id': '4bf58dd8d48988d10c951735', 'name': 'C...           43.677820
# 3   [{'id': '4bf58dd8d48988d10e941735', 'name': 'G...           43.677962
# 4   [{'id': '4bf58dd8d48988d10e941735', 'name': 'G...           43.677827
# 5   [{'id': '4bf58dd8d48988d110941735', 'name': 'I...           43.677743
# 6   [{'id': '4bf58dd8d48988d10e941735', 'name': 'G...           43.678240
# 7   [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...           43.677663
# 8   [{'id': '4bf58dd8d48988d102941735', 'name': 'Y...           43.677622
# 9   [{'id': '4bf58dd8d48988d110941735', 'name': 'I...           43.677062
# 10  [{'id': '4bf58dd8d48988d11b941735', 'name': 'P...           43.677335
# 11  [{'id': '4bf58dd8d48988d1c9941735', 'name': 'I...           43.677530
# 12  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...           43.678489
# 13  [{'id': '52f2ab2ebcbc57f1066b8b1c', 'name': 'F...           43.677999
# 14  [{'id': '4bf58dd8d48988d1d0941735', 'name': 'D...           43.677683
# 15  [{'id': '4bf58dd8d48988d114951735', 'name': 'B...           43.678507
# 16  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...           43.677267
# 17  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...           43.677308
# 18  [{'id': '4bf58dd8d48988d112941735', 'name': 'J...           43.677438
# 19  [{'id': '4bf58dd8d48988d10e941735', 'name': 'G...           43.678166
# 20  [{'id': '4bf58dd8d48988d159941735', 'name': 'T...           43.676331
# 21  [{'id': '4bf58dd8d48988d10e941735', 'name': 'G...           43.678304
# 22  [{'id': '52e81612bcbc57f1066b7a0c', 'name': 'B...           43.677769
# 23  [{'id': '4bf58dd8d48988d10e941735', 'name': 'G...           43.678263
# 24  [{'id': '4bf58dd8d48988d10e941735', 'name': 'G...           43.677689
# 25  [{'id': '4bf58dd8d48988d1f8941735', 'name': 'F...           43.678477
# 26  [{'id': '4bf58dd8d48988d118951735', 'name': 'G...           43.676790
# 27  [{'id': '4bf58dd8d48988d1ed941735', 'name': 'S...           43.676668
# 28  [{'id': '4bf58dd8d48988d147941735', 'name': 'D...           43.677594
# 29  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...           43.676643
# 30  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...           43.678645
# 31  [{'id': '4bf58dd8d48988d111941735', 'name': 'J...           43.677614
# 32  [{'id': '4bf58dd8d48988d144941735', 'name': 'C...           43.678655
# 33  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...           43.677188
# 34  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...           43.678126
# 35  [{'id': '4bf58dd8d48988d11d941735', 'name': 'S...           43.677924
# 36  [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...           43.676693
# 37  [{'id': '4bf58dd8d48988d114951735', 'name': 'B...           43.677413
# 38  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...           43.678118
# 39  [{'id': '4bf58dd8d48988d1c9941735', 'name': 'I...           43.678309
# 40  [{'id': '4bf58dd8d48988d186941735', 'name': 'L...           43.676816
# 41  [{'id': '4bf58dd8d48988d1d2941735', 'name': 'S...           43.678619
# 42  [{'id': '4bf58dd8d48988d1f8941735', 'name': 'F...           43.678613
# 43  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...           43.678730
#
#     venue.location.lng
# 0           -79.351187
# 1           -79.351434
# 2           -79.351265
# 3           -79.350196
# 4           -79.350569
# 5           -79.350115
# 6           -79.349185
# 7           -79.351313
# 8           -79.352116
# 9           -79.353934
# 10          -79.353130
# 11          -79.352295
# 12          -79.347576
# 13          -79.349969
# 14          -79.351608
# 15          -79.347678
# 16          -79.353274
# 17          -79.353066
# 18          -79.352683
# 19          -79.348927
# 20          -79.353923
# 21          -79.349486
# 22          -79.351304
# 23          -79.348648
# 24          -79.351892
# 25          -79.347811
# 26          -79.355865
# 27          -79.356602
# 28          -79.351761
# 29          -79.356846
# 30          -79.347439
# 31          -79.351641
# 32          -79.346582
# 33          -79.352975
# 34          -79.348434
# 35          -79.349307
# 36          -79.356299
# 37          -79.352734
# 38          -79.349485
# 39          -79.348105
# 40          -79.356047
# 41          -79.347024
# 42          -79.346422
# 43          -79.346188

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]
nearby_venues.head()
# Out:
#                       name        categories        lat        lng
# 0             Dolce Gelato    Ice Cream Shop  43.677773 -79.351187
# 1                 Pantheon  Greek Restaurant  43.677621 -79.351434
# 2            MenEssentials    Cosmetics Shop  43.677820 -79.351265
# 3                    Mezes  Greek Restaurant  43.677962 -79.350196
# 4  Messini Authentic Gyros  Greek Restaurant  43.677827 -79.350569
